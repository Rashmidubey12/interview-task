# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from collections import OrderedDict

from sklearn import datasets
from sklearn.preprocessing import label_binarize, LabelBinarizer
from sklearn.model_selection import train_test_split, GridSearchCV


from sklearn.metrics import precision_recall_curve
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, recall_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
DISPLAY_PRECISION = 4

# %%
pd.set_option("display.precision", DISPLAY_PRECISION)

#Get the breast cancer dataset from sklearn
dat = datasets.load_breast_cancer()
## print(dat.DESCR)  # detailed description

# %%
li_classes = [dat.target_names[1], dat.target_names[0]]
li_target = [1 if x==0 else 0 for x in list(dat.target)]
li_ftrs = list(dat.feature_names)

# %%
print("There are 2 target classes:")
print("li_classes", li_classes)
print("---")
print("Target class distribution from a total of %d target values:" % len(li_target))
print(pd.Series(li_target).value_counts())
print("---")
# Out:
# There are 2 target classes:
# li_classes ['benign', 'malignant']
# ---
# Target class distribution from a total of 569 target values:
# 0    357
# 1    212
# dtype: int64
# ---

# %%
df_all = pd.DataFrame(dat.data[:,:], columns=li_ftrs)
print("Describe dataframe, first 6 columns:")
print(df_all.iloc[:,:6].describe().to_string())
# Out:
# Describe dataframe, first 6 columns:
#        mean radius  mean texture  mean perimeter  mean area  mean smoothness  mean compactness
# count     569.0000      569.0000         569.000   569.0000         569.0000          569.0000
# mean       14.1273       19.2896          91.969   654.8891           0.0964            0.1043
# std         3.5240        4.3010          24.299   351.9141           0.0141            0.0528
# min         6.9810        9.7100          43.790   143.5000           0.0526            0.0194
# 25%        11.7000       16.1700          75.170   420.3000           0.0864            0.0649
# 50%        13.3700       18.8400          86.240   551.1000           0.0959            0.0926
# 75%        15.7800       21.8000         104.100   782.7000           0.1053            0.1304
# max        28.1100       39.2800         188.500  2501.0000           0.1634            0.3454

# %%
# Setup X and y
train_df = df_all.copy()
train_df['target'] = li_target

# %% [markdown]
# Question: (2 min)
# 1.) What is the most correlated variable to target?
#
# Question: (8 min)
# 2.) Of the top five most correlated variable what is the quatitative difference, with tolerance, between Benign(Negative) and Malignant(Positive)?

# %%
corr_matrix=df_all.corr()

# %%
corr_matrix
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                   1.0000        0.3238          0.9979     0.9874
# mean texture                  0.3238        1.0000          0.3295     0.3211
# mean perimeter                0.9979        0.3295          1.0000     0.9865
# mean area                     0.9874        0.3211          0.9865     1.0000
# mean smoothness               0.1706       -0.0234          0.2073     0.1770
# mean compactness              0.5061        0.2367          0.5569     0.4985
# mean concavity                0.6768        0.3024          0.7161     0.6860
# mean concave points           0.8225        0.2935          0.8510     0.8233
# mean symmetry                 0.1477        0.0714          0.1830     0.1513
# mean fractal dimension       -0.3116       -0.0764         -0.2615    -0.2831
# radius error                  0.6791        0.2759          0.6918     0.7326
# texture error                -0.0973        0.3864         -0.0868    -0.0663
# perimeter error               0.6742        0.2817          0.6931     0.7266
# area error                    0.7359        0.2598          0.7450     0.8001
# smoothness error             -0.2226        0.0066         -0.2027    -0.1668
# compactness error             0.2060        0.1920          0.2507     0.2126
# concavity error               0.1942        0.1433          0.2281     0.2077
# concave points error          0.3762        0.1639          0.4072     0.3723
# symmetry error               -0.1043        0.0091         -0.0816    -0.0725
# fractal dimension error      -0.0426        0.0545         -0.0055    -0.0199
# worst radius                  0.9695        0.3526          0.9695     0.9627
# worst texture                 0.2970        0.9120          0.3030     0.2875
# worst perimeter               0.9651        0.3580          0.9704     0.9591
# worst area                    0.9411        0.3435          0.9415     0.9592
# worst smoothness              0.1196        0.0775          0.1505     0.1235
# worst compactness             0.4135        0.2778          0.4558     0.3904
# worst concavity               0.5269        0.3010          0.5639     0.5126
# worst concave points          0.7442        0.2953          0.7712     0.7220
# worst symmetry                0.1640        0.1050          0.1891     0.1436
# worst fractal dimension       0.0071        0.1192          0.0510     0.0037
#
#                          mean smoothness  mean compactness  mean concavity  \
# mean radius                       0.1706            0.5061          0.6768
# mean texture                     -0.0234            0.2367          0.3024
# mean perimeter                    0.2073            0.5569          0.7161
# mean area                         0.1770            0.4985          0.6860
# mean smoothness                   1.0000            0.6591          0.5220
# mean compactness                  0.6591            1.0000          0.8831
# mean concavity                    0.5220            0.8831          1.0000
# mean concave points               0.5537            0.8311          0.9214
# mean symmetry                     0.5578            0.6026          0.5007
# mean fractal dimension            0.5848            0.5654          0.3368
# radius error                      0.3015            0.4975          0.6319
# texture error                     0.0684            0.0462          0.0762
# perimeter error                   0.2961            0.5489          0.6604
# area error                        0.2466            0.4557          0.6174
# smoothness error                  0.3324            0.1353          0.0986
# compactness error                 0.3189            0.7387          0.6703
# concavity error                   0.2484            0.5705          0.6913
# concave points error              0.3807            0.6423          0.6833
# symmetry error                    0.2008            0.2300          0.1780
# fractal dimension error           0.2836            0.5073          0.4493
# worst radius                      0.2131            0.5353          0.6882
# worst texture                     0.0361            0.2481          0.2999
# worst perimeter                   0.2389            0.5902          0.7296
# worst area                        0.2067            0.5096          0.6760
# worst smoothness                  0.8053            0.5655          0.4488
# worst compactness                 0.4725            0.8658          0.7550
# worst concavity                   0.4349            0.8163          0.8841
# worst concave points              0.5031            0.8156          0.8613
# worst symmetry                    0.3943            0.5102          0.4095
# worst fractal dimension           0.4993            0.6874          0.5149
#
#                          mean concave points  mean symmetry  \
# mean radius                           0.8225         0.1477
# mean texture                          0.2935         0.0714
# mean perimeter                        0.8510         0.1830
# mean area                             0.8233         0.1513
# mean smoothness                       0.5537         0.5578
# mean compactness                      0.8311         0.6026
# mean concavity                        0.9214         0.5007
# mean concave points                   1.0000         0.4625
# mean symmetry                         0.4625         1.0000
# mean fractal dimension                0.1669         0.4799
# radius error                          0.6980         0.3034
# texture error                         0.0215         0.1281
# perimeter error                       0.7106         0.3139
# area error                            0.6903         0.2240
# smoothness error                      0.0277         0.1873
# compactness error                     0.4904         0.4217
# concavity error                       0.4392         0.3426
# concave points error                  0.6156         0.3933
# symmetry error                        0.0954         0.4491
# fractal dimension error               0.2576         0.3318
# worst radius                          0.8303         0.1857
# worst texture                         0.2928         0.0907
# worst perimeter                       0.8559         0.2192
# worst area                            0.8096         0.1772
# worst smoothness                      0.4528         0.4267
# worst compactness                     0.6675         0.4732
# worst concavity                       0.7524         0.4337
# worst concave points                  0.9102         0.4303
# worst symmetry                        0.3757         0.6998
# worst fractal dimension               0.3687         0.4384
#
#                          mean fractal dimension  ...  worst radius  \
# mean radius                             -0.3116  ...        0.9695
# mean texture                            -0.0764  ...        0.3526
# mean perimeter                          -0.2615  ...        0.9695
# mean area                               -0.2831  ...        0.9627
# mean smoothness                          0.5848  ...        0.2131
# mean compactness                         0.5654  ...        0.5353
# mean concavity                           0.3368  ...        0.6882
# mean concave points                      0.1669  ...        0.8303
# mean symmetry                            0.4799  ...        0.1857
# mean fractal dimension                   1.0000  ...       -0.2537
# radius error                             0.0001  ...        0.7151
# texture error                            0.1642  ...       -0.1117
# perimeter error                          0.0398  ...        0.6972
# area error                              -0.0902  ...        0.7574
# smoothness error                         0.4020  ...       -0.2307
# compactness error                        0.5598  ...        0.2046
# concavity error                          0.4466  ...        0.1869
# concave points error                     0.3412  ...        0.3581
# symmetry error                           0.3450  ...       -0.1281
# fractal dimension error                  0.6881  ...       -0.0375
# worst radius                            -0.2537  ...        1.0000
# worst texture                           -0.0513  ...        0.3599
# worst perimeter                         -0.2052  ...        0.9937
# worst area                              -0.2319  ...        0.9840
# worst smoothness                         0.5049  ...        0.2166
# worst compactness                        0.4588  ...        0.4758
# worst concavity                          0.3462  ...        0.5740
# worst concave points                     0.1753  ...        0.7874
# worst symmetry                           0.3340  ...        0.2435
# worst fractal dimension                  0.7673  ...        0.0935
#
#                          worst texture  worst perimeter  worst area  \
# mean radius                     0.2970           0.9651      0.9411
# mean texture                    0.9120           0.3580      0.3435
# mean perimeter                  0.3030           0.9704      0.9415
# mean area                       0.2875           0.9591      0.9592
# mean smoothness                 0.0361           0.2389      0.2067
# mean compactness                0.2481           0.5902      0.5096
# mean concavity                  0.2999           0.7296      0.6760
# mean concave points             0.2928           0.8559      0.8096
# mean symmetry                   0.0907           0.2192      0.1772
# mean fractal dimension         -0.0513          -0.2052     -0.2319
# radius error                    0.1948           0.7197      0.7515
# texture error                   0.4090          -0.1022     -0.0832
# perimeter error                 0.2004           0.7210      0.7307
# area error                      0.1965           0.7612      0.8114
# smoothness error               -0.0747          -0.2173     -0.1822
# compactness error               0.1430           0.2605      0.1994
# concavity error                 0.1002           0.2267      0.1884
# concave points error            0.0867           0.3950      0.3423
# symmetry error                 -0.0775          -0.1038     -0.1103
# fractal dimension error        -0.0032          -0.0010     -0.0227
# worst radius                    0.3599           0.9937      0.9840
# worst texture                   1.0000           0.3651      0.3458
# worst perimeter                 0.3651           1.0000      0.9776
# worst area                      0.3458           0.9776      1.0000
# worst smoothness                0.2254           0.2368      0.2091
# worst compactness               0.3608           0.5294      0.4383
# worst concavity                 0.3684           0.6183      0.5433
# worst concave points            0.3598           0.8163      0.7474
# worst symmetry                  0.2330           0.2695      0.2091
# worst fractal dimension         0.2191           0.1390      0.0796
#
#                          worst smoothness  worst compactness  worst concavity  \
# mean radius                        0.1196             0.4135           0.5269
# mean texture                       0.0775             0.2778           0.3010
# mean perimeter                     0.1505             0.4558           0.5639
# mean area                          0.1235             0.3904           0.5126
# mean smoothness                    0.8053             0.4725           0.4349
# mean compactness                   0.5655             0.8658           0.8163
# mean concavity                     0.4488             0.7550           0.8841
# mean concave points                0.4528             0.6675           0.7524
# mean symmetry                      0.4267             0.4732           0.4337
# mean fractal dimension             0.5049             0.4588           0.3462
# radius error                       0.1419             0.2871           0.3806
# texture error                     -0.0737            -0.0924          -0.0690
# perimeter error                    0.1301             0.3419           0.4189
# area error                         0.1254             0.2833           0.3851
# smoothness error                   0.3145            -0.0556          -0.0583
# compactness error                  0.2274             0.6788           0.6391
# concavity error                    0.1685             0.4849           0.6626
# concave points error               0.2154             0.4529           0.5496
# symmetry error                    -0.0127             0.0603           0.0371
# fractal dimension error            0.1706             0.3902           0.3800
# worst radius                       0.2166             0.4758           0.5740
# worst texture                      0.2254             0.3608           0.3684
# worst perimeter                    0.2368             0.5294           0.6183
# worst area                         0.2091             0.4383           0.5433
# worst smoothness                   1.0000             0.5682           0.5185
# worst compactness                  0.5682             1.0000           0.8923
# worst concavity                    0.5185             0.8923           1.0000
# worst concave points               0.5477             0.8011           0.8554
# worst symmetry                     0.4938             0.6144           0.5325
# worst fractal dimension            0.6176             0.8105           0.6865
#
#                          worst concave points  worst symmetry  \
# mean radius                            0.7442          0.1640
# mean texture                           0.2953          0.1050
# mean perimeter                         0.7712          0.1891
# mean area                              0.7220          0.1436
# mean smoothness                        0.5031          0.3943
# mean compactness                       0.8156          0.5102
# mean concavity                         0.8613          0.4095
# mean concave points                    0.9102          0.3757
# mean symmetry                          0.4303          0.6998
# mean fractal dimension                 0.1753          0.3340
# radius error                           0.5311          0.0945
# texture error                         -0.1196         -0.1282
# perimeter error                        0.5549          0.1099
# area error                             0.5382          0.0741
# smoothness error                      -0.1020         -0.1073
# compactness error                      0.4832          0.2779
# concavity error                        0.4405          0.1978
# concave points error                   0.6024          0.1431
# symmetry error                        -0.0304          0.3894
# fractal dimension error                0.2152          0.1111
# worst radius                           0.7874          0.2435
# worst texture                          0.3598          0.2330
# worst perimeter                        0.8163          0.2695
# worst area                             0.7474          0.2091
# worst smoothness                       0.5477          0.4938
# worst compactness                      0.8011          0.6144
# worst concavity                        0.8554          0.5325
# worst concave points                   1.0000          0.5025
# worst symmetry                         0.5025          1.0000
# worst fractal dimension                0.5111          0.5378
#
#                          worst fractal dimension
# mean radius                               0.0071
# mean texture                              0.1192
# mean perimeter                            0.0510
# mean area                                 0.0037
# mean smoothness                           0.4993
# mean compactness                          0.6874
# mean concavity                            0.5149
# mean concave points                       0.3687
# mean symmetry                             0.4384
# mean fractal dimension                    0.7673
# radius error                              0.0496
# texture error                            -0.0457
# perimeter error                           0.0854
# area error                                0.0175
# smoothness error                          0.1015
# compactness error                         0.5910
# concavity error                           0.4393
# concave points error                      0.3107
# symmetry error                            0.0781
# fractal dimension error                   0.5913
# worst radius                              0.0935
# worst texture                             0.2191
# worst perimeter                           0.1390
# worst area                                0.0796
# worst smoothness                          0.6176
# worst compactness                         0.8105
# worst concavity                           0.6865
# worst concave points                      0.5111
# worst symmetry                            0.5378
# worst fractal dimension                   1.0000
#
# [30 rows x 30 columns]

# %%
df_all.corrwith(train_df['target'])
# Out:
# mean radius                0.7300
# mean texture               0.4152
# mean perimeter             0.7426
# mean area                  0.7090
# mean smoothness            0.3586
# mean compactness           0.5965
# mean concavity             0.6964
# mean concave points        0.7766
# mean symmetry              0.3305
# mean fractal dimension    -0.0128
# radius error               0.5671
# texture error             -0.0083
# perimeter error            0.5561
# area error                 0.5482
# smoothness error          -0.0670
# compactness error          0.2930
# concavity error            0.2537
# concave points error       0.4080
# symmetry error            -0.0065
# fractal dimension error    0.0780
# worst radius               0.7765
# worst texture              0.4569
# worst perimeter            0.7829
# worst area                 0.7338
# worst smoothness           0.4215
# worst compactness          0.5910
# worst concavity            0.6596
# worst concave points       0.7936
# worst symmetry             0.4163
# worst fractal dimension    0.3239
# dtype: float64

# %% [markdown]
# # worst concave points is most correlated with target
